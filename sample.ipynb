# %%
import json
with open("/home/dung/Study/Code/Python/Cross-lingual/Few_shot/evaluation/evaluation_rs/Go/fewshot/CodeLlama-7b-Instruct-hf/Go.final.generated.jsonl","r") as f:
    data = [json.loads(line) for line in f]

# %%
print(data[1]["prompt"])
# Out:
# <s>[INST] <<SYS>>
# You are a helpful coding assistant. Your task is to generate unittest for a given function.
# <</SYS>>
#
# Given the following related examples:
#
# Example 1:
# public int isPalindrome(String A) {
#         int len = A.length();
#         int i = 0;
#         int j = len - 1;
#         while (i < j) {
#             // find the right character to compare
#             while (i < j && !Character.isLetterOrDigit(A.charAt(i))) {
#                 i++;
#             }
#             while (i < j && !Character.isLetterOrDigit(A.charAt(j))) {
#                 j--;
#             }
#             if (Character.toLowerCase(A.charAt(i)) != Character.toLowerCase(A.charAt(j))) {
#                 return 0;
#             }
#             i++;
#             j--;
#         }
#         return 1;
#     }
#
# @Test
#     public void Test4() {
#         String A = "      ";
#         int actual = solution.isPalindrome(A);
#         int expected = 1;
# ...

# %%
import json
with open("/home/dung/Study/Code/Python/Cross-lingual/Few_shot/evaluation/evaluation_rs/Go/fewshot/CodeLlama-7b-Instruct-hf/Go.final.generated.jsonl","r") as f:
    data1 = [json.loads(line) for line in f]
print(data[0]["response"][0])
# Out:
# {'task_id': 0,
# ...
